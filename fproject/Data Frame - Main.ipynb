# %% [markdown]
# # Questions and unanswered questions

# %% [markdown]
# # Main Data Frame
# - Topics
# - Users
# - replies/conversations
# - url count
# - emoji
#
# Using a variety of tools to get everything into one dataframe ready for analysis and visualisation in excel and Tableau

# %% [markdown]
# ## Contents
# 1. import csv
# 2. basic cleaning and creation of text Blob
# 3. word counts of each post and of specific words in the whole text
# 4. Sentiment Analysis - Rating (good, neutral, poor)- per post and per user
# 5. Extract emoji to new column
# 6. Count url and delete from text
# 7. Remove stop words + symbols and noise you know of (maual addition to the stop words list)

# %% [markdown]
# ## 1. import csv

# %%
import pandas as pd
from textblob import TextBlob
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import re

# %%
df = pd.read_csv (r'general.csv')

# %%
df
# Out:
#                  time   name  \
# 0    21/03/2021 17:04  siand
# 1    23/03/2021 07:02    NaN
# 2    23/03/2021 07:26    NaN
# 3    23/03/2021 07:41    NaN
# 4    23/03/2021 07:42    NaN
# ..                ...    ...
# 625  27/04/2021 10:40    NaN
# 626  27/04/2021 10:40  siand
# 627  27/04/2021 10:40  siand
# 628  27/04/2021 10:41  siand
# 629  27/04/2021 10:42  siand
#
#                                                   text  subtype  num_reply  \
# 0                     hi everyone! see you tomorrow :)      NaN        NaN
# 1                                                 same      NaN        NaN
# 2    same, can you give access to <mailto:andreatog...      NaN        NaN
# 3    my address is <mailto:karina.condeixa@gmail.co...      NaN        NaN
# 4    Letâ€™s try using Slack forâ€¦how do we join z...      NaN        3.0
# ..                                                 ...      ...        ...
# 625  just to warn you though, the whole zip file of...      NaN        NaN
# 626  because it contains text files with the links,...      NaN        NaN
# 627         but yes i am sure you guys can wrangle it!      NaN        NaN
# 628                  just your average 200 mb file lol      NaN        NaN
# 629  ok so we think we have a plan for the notion c...      NaN        NaN
#
#      num_participants         user      thred_ts parent_user_id  Unnamed: 9  \
# 0                 NaN  U01RW140HBP           NaN            NaN         NaN
# 1                 NaN  U01S0MFJ3HR  1.616443e+09    U01SJKB2MG8         NaN
# 2                 NaN  U01SD3CDH9P  1.616443e+09    U01SJKB2MG8         NaN
# 3                 NaN  U01S79YDELR  1.616443e+09    U01SJKB2MG8         NaN
# 4                 NaN  U01RS9Y6UJH  1.616485e+09            NaN         NaN
# ..                ...          ...           ...            ...         ...
# 625               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP         NaN
# 626               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP         NaN
# 627               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP         NaN
# 628               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP         NaN
# 629               NaN  U01RW140HBP           NaN            NaN         NaN
#
#      Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 625          NaN          NaN          NaN          NaN          NaN
# 626          NaN          NaN          NaN          NaN          NaN
# 627          NaN          NaN          NaN          NaN          NaN
# 628          NaN          NaN          NaN          NaN          NaN
# 629          NaN          NaN          NaN          NaN          NaN
#
#      Unnamed: 15  Unnamed: 16  Unnamed: 17 Unnamed: 18
# 0            NaN          NaN          NaN         NaN
# 1            NaN          NaN          NaN         NaN
# 2            NaN          NaN          NaN         NaN
# 3            NaN          NaN          NaN         NaN
# 4            NaN          NaN          NaN         NaN
# ..           ...          ...          ...         ...
# 625          NaN          NaN          NaN         NaN
# 626          NaN          NaN          NaN         NaN
# 627          NaN          NaN          NaN         NaN
# 628          NaN          NaN          NaN         NaN
# 629          NaN          NaN          NaN         NaN
#
# [630 rows x 19 columns]

# %%
df = df.drop(columns = ['Unnamed: 9','Unnamed: 10','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14','Unnamed: 15','Unnamed: 16','Unnamed: 17','Unnamed: 18'])

# %%
df.shape
# Out:
# (630, 9)

# %%
df
# Out:
#                  time   name  \
# 0    21/03/2021 17:04  siand
# 1    23/03/2021 07:02    NaN
# 2    23/03/2021 07:26    NaN
# 3    23/03/2021 07:41    NaN
# 4    23/03/2021 07:42    NaN
# ..                ...    ...
# 625  27/04/2021 10:40    NaN
# 626  27/04/2021 10:40  siand
# 627  27/04/2021 10:40  siand
# 628  27/04/2021 10:41  siand
# 629  27/04/2021 10:42  siand
#
#                                                   text  subtype  num_reply  \
# 0                     hi everyone! see you tomorrow :)      NaN        NaN
# 1                                                 same      NaN        NaN
# 2    same, can you give access to <mailto:andreatog...      NaN        NaN
# 3    my address is <mailto:karina.condeixa@gmail.co...      NaN        NaN
# 4    Letâ€™s try using Slack forâ€¦how do we join z...      NaN        3.0
# ..                                                 ...      ...        ...
# 625  just to warn you though, the whole zip file of...      NaN        NaN
# 626  because it contains text files with the links,...      NaN        NaN
# 627         but yes i am sure you guys can wrangle it!      NaN        NaN
# 628                  just your average 200 mb file lol      NaN        NaN
# 629  ok so we think we have a plan for the notion c...      NaN        NaN
#
#      num_participants         user      thred_ts parent_user_id
# 0                 NaN  U01RW140HBP           NaN            NaN
# 1                 NaN  U01S0MFJ3HR  1.616443e+09    U01SJKB2MG8
# 2                 NaN  U01SD3CDH9P  1.616443e+09    U01SJKB2MG8
# 3                 NaN  U01S79YDELR  1.616443e+09    U01SJKB2MG8
# 4                 NaN  U01RS9Y6UJH  1.616485e+09            NaN
# ..                ...          ...           ...            ...
# 625               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP
# 626               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP
# 627               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP
# 628               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP
# 629               NaN  U01RW140HBP           NaN            NaN
#
# [630 rows x 9 columns]

# %% [markdown]
# ## 2. basic cleaning and creation of text Blob

# %%
#Getting rid of empty fields in review text
df['text'].replace('', np.nan, inplace=True)
df.dropna(subset=['text'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 597 entries, 0 to 629
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   time              597 non-null    object
#  1   name              397 non-null    object
#  2   text              597 non-null    object
#  3   subtype           0 non-null      float64
#  4   num_reply         75 non-null     float64
#  5   num_participants  0 non-null      float64
#  6   user              597 non-null    object
#  7   thred_ts          438 non-null    float64
#  8   parent_user_id    363 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 46.6+ KB

# %%
howdofeel = TextBlob("nice")
howdofeel.sentiment
# Out:
# Sentiment(polarity=0.6, subjectivity=1.0)

# %%
#random look into comments to check their nature
df['text'].iloc[6]
# Out:
# 'I believe that is the same link'

# %%
df['text'].iloc[66]
# Out:
# '<https://zoom.us/j/877626245>\npw: 986565'

# %%
df.head()
# Out:
#                time   name                                               text  \
# 0  21/03/2021 17:04  siand                   hi everyone! see you tomorrow :)
# 1  23/03/2021 07:02    NaN                                               same
# 2  23/03/2021 07:26    NaN  same, can you give access to <mailto:andreatog...
# 3  23/03/2021 07:41    NaN  my address is <mailto:karina.condeixa@gmail.co...
# 4  23/03/2021 07:42    NaN  Letâ€™s try using Slack forâ€¦how do we join z...
#
#    subtype  num_reply  num_participants         user      thred_ts  \
# 0      NaN        NaN               NaN  U01RW140HBP           NaN
# 1      NaN        NaN               NaN  U01S0MFJ3HR  1.616443e+09
# 2      NaN        NaN               NaN  U01SD3CDH9P  1.616443e+09
# 3      NaN        NaN               NaN  U01S79YDELR  1.616443e+09
# 4      NaN        3.0               NaN  U01RS9Y6UJH  1.616485e+09
#
#   parent_user_id
# 0            NaN
# 1    U01SJKB2MG8
# 2    U01SJKB2MG8
# 3    U01SJKB2MG8
# 4            NaN

# %%
df['thanks'] = ''

# %%
# count and add thanks as a column
for a in df['text']:
    if re.findall(r'\thank', a):
        df['thanks'] = 1
    else:
        df['thanks'] = 0

# %%
df.tail(50)
# Out:
#                  time       name  \
# 579  26/04/2021 06:54        NaN
# 580  26/04/2021 06:54      Thanh
# 581  26/04/2021 06:56        NaN
# 582  26/04/2021 07:15        Sam
# 583  26/04/2021 07:37      siand
# 584  26/04/2021 08:04        NaN
# 585  26/04/2021 12:00  Josephine
# 586  26/04/2021 12:09        NaN
# 587  26/04/2021 12:11        NaN
# 588  26/04/2021 12:12        NaN
# 589  26/04/2021 12:15        NaN
# 590  26/04/2021 12:17        NaN
# 591  26/04/2021 12:19        NaN
# 593  26/04/2021 12:26        NaN
# 594  26/04/2021 14:10      siand
# 595  26/04/2021 15:03      Lilla
# 596  26/04/2021 15:03      Thanh
# 597  26/04/2021 15:07      siand
# 598  26/04/2021 15:10    Florian
# 599  26/04/2021 15:11      siand
# 600  26/04/2021 15:13    Florian
# 601  26/04/2021 15:28      siand
# 602  26/04/2021 15:31      siand
# 603  26/04/2021 15:44        NaN
# 604  26/04/2021 16:34        Sam
# 605  26/04/2021 16:50      siand
# 606  27/04/2021 07:14      siand
# 607  27/04/2021 07:25      siand
# 608  27/04/2021 07:38        Sam
# 609  27/04/2021 07:41      siand
# 610  27/04/2021 07:45        Sam
# 611  27/04/2021 08:31        Sam
# 612  27/04/2021 08:33      siand
# 613  27/04/2021 10:29        NaN
# 614  27/04/2021 10:29      siand
# 615  27/04/2021 10:30      siand
# 616  27/04/2021 10:30      Thamo
# 617  27/04/2021 10:30      Thamo
# 618  27/04/2021 10:30      Thanh
# 619  27/04/2021 10:31      siand
# 620  27/04/2021 10:36      siand
# 621  27/04/2021 10:37      Thamo
# 622  27/04/2021 10:37      Thamo
# 623  27/04/2021 10:39        NaN
# 624  27/04/2021 10:39      siand
# 625  27/04/2021 10:40        NaN
# 626  27/04/2021 10:40      siand
# 627  27/04/2021 10:40      siand
# 628  27/04/2021 10:41      siand
# 629  27/04/2021 10:42      siand
#
#                                                   text  subtype  num_reply  \
# 579         I missed that, but I want to go next time.      NaN        NaN
# 580        Yes, it was so pleasant to meet all of you!      NaN        NaN
# 581  I think the idea is to give more notice next t...      NaN        NaN
# 582  as long weâ€™re all in some polyamorous relati...      NaN        NaN
# 583  ironhack does not condone corona restriction r...      NaN        NaN
# 584                                           this one      NaN        3.0
# 585  we start at 14:30 right? Sorry I'm not sure an...      NaN        NaN
# 586  Yes! Can someone share here the Dataset from K...      NaN        4.0
# 587    <https://www.kaggle.com/carrie1/ecommerce-data>      NaN        NaN
# 588            do you want the file or is the link ok?      NaN        NaN
# 589  Thank you <@U01S79YDELR> :slightly_smiling_fac...      NaN        NaN
# 590  is this with the modifications she made in class?      NaN        NaN
# 591                 uploading. slowly.. <@U01S081EULS>      NaN        NaN
# 593  <!channel> Hey Class :slightly_smiling_face:\n...      NaN        NaN
# 594  i have published my class workbook from today ...      NaN        NaN
# 595                               it would be awesome!      NaN        NaN
# 596  no, i don't think this is the modified version...      NaN        NaN
# 597  hmmm let me think on it - could it be a good w...      NaN        NaN
# 598  we could create a different view of the the ca...      NaN        NaN
# 599  yes i think so - list is probably a good one t...      NaN        NaN
# 600                 ok, Table and List views are added      NaN        NaN
# 601                                            lovely!      NaN        NaN
# 602  it seems Notion havent finished making their a...      NaN        NaN
# 603                         ok :slightly_smiling_face:      NaN        NaN
# 604  <https://www.berliner-zeitung.de/en/snow-and-s...      NaN        NaN
# 605                                             brrrrr      NaN        NaN
# 606  todays *job inspirations* - from Dyson enginee...      NaN        NaN
# 607  and from the other end of the spectrum - anoth...      NaN        5.0
# 608  I was eyeing up a couple of jobs at HomeToGo i...      NaN        NaN
# 609  looks like a fun company - bound to have good ...      NaN        NaN
# 610  most importantly: walking distance from home :...      NaN        NaN
# 611  <https://company.onefootball.com/jobs/data-ana...      NaN        NaN
# 612  oh the sports analysis industry is massively c...      NaN        NaN
# 613                                              sorry      NaN        NaN
# 614  If you find yourself with some downtime this a...      NaN       12.0
# 615  ( i find bad news when delivered by a cute dog...      NaN        1.0
# 616  Is there an easy way to copy those notion page...      NaN        NaN
# 617                                              defo!      NaN        NaN
# 618  it's probably not possible to copy the whole B...      NaN        NaN
# 619  not sureâ€¦ feel free to explore! i havent fou...      NaN        NaN
# 620  hmm :thinking_face: it looks like i might be a...      NaN        NaN
# 621                Yes please! :slightly_smiling_face:      NaN        NaN
# 622                         We can wrangle it :python:      NaN        NaN
# 623  example this is what the dashboard lab looks like      NaN        NaN
# 624  cool i can do that ! ill make myself a reminde...      NaN        NaN
# 625  just to warn you though, the whole zip file of...      NaN        NaN
# 626  because it contains text files with the links,...      NaN        NaN
# 627         but yes i am sure you guys can wrangle it!      NaN        NaN
# 628                  just your average 200 mb file lol      NaN        NaN
# 629  ok so we think we have a plan for the notion c...      NaN        NaN
#
#      num_participants         user      thred_ts parent_user_id  thanks
# 579               NaN  U01S79YDELR  1.619420e+09    U01RS9Y6UJH       0
# 580               NaN  U01RXCQHMHT  1.619420e+09    U01RS9Y6UJH       0
# 581               NaN  U01RS9Y6UJH  1.619420e+09    U01RS9Y6UJH       0
# 582               NaN  U01S7KCL3DF  1.619420e+09    U01RS9Y6UJH       0
# 583               NaN  U01RW140HBP  1.619420e+09    U01RS9Y6UJH       0
# 584               NaN  U01RXCQHMHT  1.619424e+09            NaN       0
# 585               NaN  U01RN7BVD1C           NaN            NaN       0
# 586               NaN  U01S081EULS  1.619439e+09            NaN       0
# 587               NaN  U01S79YDELR  1.619439e+09    U01S081EULS       0
# 588               NaN  U01S79YDELR  1.619439e+09    U01S081EULS       0
# 589               NaN  U01S081EULS  1.619439e+09    U01S081EULS       0
# 590               NaN  U01S79YDELR  1.619424e+09    U01RXCQHMHT       0
# 591               NaN  U01S79YDELR           NaN            NaN       0
# 593               NaN  U01RUTP1ZQB           NaN            NaN       0
# 594               NaN  U01RW140HBP           NaN            NaN       0
# 595               NaN  U01SK96QF5E  1.619368e+09    U01S79YDELR       0
# 596               NaN  U01RXCQHMHT  1.619424e+09    U01RXCQHMHT       0
# 597               NaN  U01RW140HBP  1.619368e+09    U01S79YDELR       0
# 598               NaN  U01SJKB2MG8  1.619368e+09    U01S79YDELR       0
# 599               NaN  U01RW140HBP  1.619368e+09    U01S79YDELR       0
# 600               NaN  U01SJKB2MG8  1.619368e+09    U01S79YDELR       0
# 601               NaN  U01RW140HBP  1.619368e+09    U01S79YDELR       0
# 602               NaN  U01RW140HBP  1.619368e+09    U01S79YDELR       0
# 603               NaN  U01S79YDELR  1.619424e+09    U01RXCQHMHT       0
# 604               NaN  U01S7KCL3DF  1.619420e+09    U01RS9Y6UJH       0
# 605               NaN  U01RW140HBP  1.619420e+09    U01RS9Y6UJH       0
# 606               NaN  U01RW140HBP           NaN            NaN       0
# 607               NaN  U01RW140HBP  1.619508e+09            NaN       0
# 608               NaN  U01S7KCL3DF  1.619508e+09    U01RW140HBP       0
# 609               NaN  U01RW140HBP  1.619508e+09    U01RW140HBP       0
# 610               NaN  U01S7KCL3DF  1.619508e+09    U01RW140HBP       0
# 611               NaN  U01S7KCL3DF  1.619508e+09    U01RW140HBP       0
# 612               NaN  U01RW140HBP  1.619508e+09    U01RW140HBP       0
# 613               NaN  U01RW140HBP           NaN            NaN       0
# 614               NaN  U01RW140HBP  1.619519e+09            NaN       0
# 615               NaN  U01RW140HBP  1.619519e+09            NaN       0
# 616               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 617               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 618               NaN  U01RXCQHMHT  1.619519e+09    U01RW140HBP       0
# 619               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 620               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 621               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 622               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 623               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 624               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 625               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 626               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 627               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 628               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 629               NaN  U01RW140HBP           NaN            NaN       0

# %%
#Pulling out the text from review text, ready for analysis. 
blob = [TextBlob(i) for i in df['text']]#

# %% [markdown]
# ## 3. word counts of each post and of specific words in the whole text
# What frequent words can we find?

# %%
# How many times did we say thanks: 
thanks = []

for a in range(len(blob)):
    x = blob[a].words.count('thanks')
    y = blob[a].words.count('thank you')
    c = blob[a].words.count('ta')
    thanks.append(x)
    thanks.append(y)
    thanks.append(c)

# %%
sum(thanks)
# it would be nice to have thanks as a column in the data frame - go back and do this.
# Out:
# 39

# %%
# How many times did we say nice: 
nice = []

for a in range(len(blob)):
    y = blob[a].words.count('nice')
    nice.append(y)

# %%
sum(nice)
# Out:
# 7

# %%
# How many times did we say Does anyone: 
does_anyone = []

for a in range(len(blob)):
    y = blob[a].words.count('does')
    does_anyone.append(y)

# %%
sum(does_anyone)
# Out:
# 8

# %%
# How many times did we say cool: 
cool = []

for a in range(len(blob)):
    y = blob[a].words.count('cool')
    cool.append(y)

# %%
sum(cool)
# Out:
# 3

# %% [markdown]
# ## 4. Sentiment Analysis - Rating (good, neutral, poor)- per post and per user

# %%
def sentiment(text):
    try:
        return TextBlob(text).sentiment
    except:
        return None

# %%
df['polarity']=df['text'].apply(sentiment).apply(lambda x: x[0])

# %%
df.head(60)
# Out:
#                 time       name  \
# 0   21/03/2021 17:04      siand
# 1   23/03/2021 07:02        NaN
# 2   23/03/2021 07:26        NaN
# 3   23/03/2021 07:41        NaN
# 4   23/03/2021 07:42        NaN
# 5   23/03/2021 07:42      Thamo
# 6   23/03/2021 07:42        NaN
# 7   23/03/2021 07:43        NaN
# 8   23/03/2021 07:44        NaN
# 9   23/03/2021 07:44      Thamo
# 10  23/03/2021 07:49        NaN
# 11  23/03/2021 07:50        NaN
# 12  23/03/2021 08:00        Sam
# 13  23/03/2021 08:00        NaN
# 14  23/03/2021 08:01  Alexandre
# 15  23/03/2021 08:01  Alexandre
# 16  23/03/2021 08:01        Sam
# 17  23/03/2021 08:01      Thamo
# 18  23/03/2021 08:02        NaN
# 19  23/03/2021 08:02      siand
# 20  23/03/2021 08:02  Alexandre
# 21  23/03/2021 08:03        NaN
# 22  23/03/2021 08:03    Florian
# 23  23/03/2021 08:04        NaN
# 24  23/03/2021 08:04        NaN
# 25  23/03/2021 08:05        NaN
# 26  23/03/2021 08:05        NaN
# 27  23/03/2021 08:10    Florian
# 28  23/03/2021 08:10        NaN
# 29  23/03/2021 08:10        NaN
# 30  23/03/2021 08:11        NaN
# 31  23/03/2021 08:13      Thanh
# 32  23/03/2021 08:13        NaN
# 33  23/03/2021 08:13  Josephine
# 34  23/03/2021 08:13      siand
# 35  23/03/2021 08:13      siand
# 36  23/03/2021 08:15      siand
# 37  23/03/2021 08:16        NaN
# 38  23/03/2021 08:27      siand
# 39  23/03/2021 08:42      siand
# 40  23/03/2021 08:49        NaN
# 42  23/03/2021 10:09        Sam
# 43  23/03/2021 10:09      siand
# 44  23/03/2021 10:10      Thamo
# 45  23/03/2021 10:11      Thamo
# 46  23/03/2021 10:14      siand
# 47  23/03/2021 10:14        NaN
# 48  23/03/2021 10:18        NaN
# 49  23/03/2021 10:21      siand
# 50  23/03/2021 10:22        NaN
# 51  23/03/2021 10:22    Florian
# 55  23/03/2021 12:12      siand
# 56  23/03/2021 12:12      siand
# 58  23/03/2021 12:14      siand
# 59  23/03/2021 13:03        Sam
# 60  23/03/2021 14:58      Thanh
# 61  23/03/2021 14:59      siand
# 62  23/03/2021 14:59  Josephine
# 63  23/03/2021 15:01        NaN
# 64  23/03/2021 15:04        NaN
#
#                                                  text  subtype  num_reply  \
# 0                    hi everyone! see you tomorrow :)      NaN        NaN
# 1                                                same      NaN        NaN
# 2   same, can you give access to <mailto:andreatog...      NaN        NaN
# 3   my address is <mailto:karina.condeixa@gmail.co...      NaN        NaN
# 4   Letâ€™s try using Slack forâ€¦how do we join z...      NaN        3.0
# 5   Same link as yesterday, the message is pinned ...      NaN        NaN
# 6                     I believe that is the same link      NaN        NaN
# 7                                           ok thanks      NaN        NaN
# 8                                       Thanks Thamo!      NaN        NaN
# 9                                         :v:welcome       NaN        NaN
# 10                                            morning      NaN        NaN
# 11  my adress is: <mailto:anja.fechner@live.de|anj...      NaN        NaN
# 12  <https://ironhack.zoom.us/j/877626245?pwd=YjFt...      NaN        2.0
# 13                                 not working for me      NaN        NaN
# 14                      <https://zoom.us/j/877626245>      NaN        NaN
# 15                                          pw 986565      NaN        NaN
# 16                      this one no good? i'll delete      NaN        NaN
# 17                  seems like that but I am not sure      NaN        NaN
# 18                   shows no upcoming meetings today      NaN        NaN
# 19                                its running  Karina      NaN        NaN
# 20            did you open the link in the navigator?      NaN        NaN
# 21                         yes and then using the app      NaN        NaN
# 22  <!channel>,\ncan you access the content now? W...      NaN        1.0
# 23                                mine not signing in      NaN        NaN
# 24  yes, thanks. I have problems to go the the cla...      NaN        NaN
# 25             <@U01SJKB2MG8> i cannot join the class      NaN        NaN
# 26  could we have the user name and signing like t...      NaN        2.0
# 27  <!channel>!\nQUIZME after the coffee break!\ng...      NaN        NaN
# 28                    used another laptop. But thanks      NaN        NaN
# 29                                             Karina      NaN        NaN
# 30                              i am going to restart      NaN        NaN
# 31                                     <@U01SD3CDH9P>      NaN        NaN
# 32   yes, finaly I could enter to the zoom, the class      NaN        4.0
# 33                Yeyyyy it works :heart_eyes: Thanks      NaN        NaN
# 34  what happened? did you have to do something sp...      NaN        NaN
# 35                                     PINÂ *9973821*      NaN        NaN
# 36  so weird, normally this works fineâ€¦ just go ...      NaN        NaN
# 37                thanks, it finally worked for me :D      NaN        NaN
# 38      maybe worth clearing the cache or something ?      NaN        NaN
# 39  notion link <https://www.notion.so/ironhack/Be...      NaN        NaN
# 40          it doesnt show up the docx file attached?      NaN        NaN
# 42  On histograms in Excel....I thought State woul...      NaN       10.0
# 43  tip of the day : <https://statistics.laerd.com...      NaN        NaN
# 44                               Just one column, yes      NaN        NaN
# 45                      Try another type of histogram      NaN        NaN
# 46  I would use a pivot table to sum up how many r...      NaN        NaN
# 47                                               eg :      NaN        NaN
# 48  How can I open the solution code? Can I import...      NaN        NaN
# 49                         <@U01SJKB2MG8> one for you      NaN        NaN
# 50           column chart gives me this peach :smile:      NaN        NaN
# 51  yes. Start a notebook server, wait until the b...      NaN        NaN
# 55  absolutely stunning :slightly_smiling_face: ye...      NaN        NaN
# 56           dont you love how intutive excel is haha      NaN        NaN
# 58  or use the FREQUENCY function - long winded bu...      NaN        NaN
# 59                        ok cool homework for later!      NaN        NaN
# 60  <@U01RW140HBP> Thank you for today's lessons a...      NaN        1.0
# 61  of course! I am sorry i overran the lesson. yo...      NaN        NaN
# 62            and thanks for getting Robert on board!      NaN        NaN
# 63  siand can you share your Jupyter file from tod...      NaN        1.0
# 64                                         of course!      NaN        NaN
#
#     num_participants         user      thred_ts parent_user_id  thanks  \
# 0                NaN  U01RW140HBP           NaN            NaN       0
# 1                NaN  U01S0MFJ3HR  1.616443e+09    U01SJKB2MG8       0
# 2                NaN  U01SD3CDH9P  1.616443e+09    U01SJKB2MG8       0
# 3                NaN  U01S79YDELR  1.616443e+09    U01SJKB2MG8       0
# 4                NaN  U01RS9Y6UJH  1.616485e+09            NaN       0
# 5                NaN  U01S7BM4N81  1.616485e+09    U01RS9Y6UJH       0
# 6                NaN  U01S79YDELR  1.616485e+09    U01RS9Y6UJH       0
# 7                NaN  U01RS9Y6UJH  1.616485e+09    U01RS9Y6UJH       0
# 8                NaN  U01S79YDELR           NaN            NaN       0
# 9                NaN  U01S7BM4N81           NaN            NaN       0
# 10               NaN  U01RW2X7S9Z           NaN            NaN       0
# 11               NaN  U01S0MFJ3HR  1.616443e+09    U01SJKB2MG8       0
# 12               NaN  U01S7KCL3DF  1.616486e+09            NaN       0
# 13               NaN  U01S79YDELR           NaN            NaN       0
# 14               NaN  U01RW2X7S9Z           NaN            NaN       0
# 15               NaN  U01RW2X7S9Z           NaN            NaN       0
# 16               NaN  U01S7KCL3DF  1.616486e+09    U01S7KCL3DF       0
# 17               NaN  U01S7BM4N81  1.616486e+09    U01S7KCL3DF       0
# 18               NaN  U01S79YDELR           NaN            NaN       0
# 19               NaN  U01RW140HBP           NaN            NaN       0
# 20               NaN  U01RW2X7S9Z           NaN            NaN       0
# 21               NaN  U01S79YDELR           NaN            NaN       0
# 22               NaN  U01SJKB2MG8  1.616487e+09            NaN       0
# 23               NaN  U01S0P26NKD           NaN            NaN       0
# 24               NaN  U01S79YDELR           NaN            NaN       0
# 25               NaN  U01S79YDELR           NaN            NaN       0
# 26               NaN  U01S0P26NKD  1.616487e+09            NaN       0
# 27               NaN  U01SJKB2MG8           NaN            NaN       0
# 28               NaN  U01S0P26NKD           NaN            NaN       0
# 29               NaN  U01S79YDELR  1.616487e+09    U01S0P26NKD       0
# 30               NaN  U01S79YDELR  1.616487e+09    U01S0P26NKD       0
# 31               NaN  U01RXCQHMHT           NaN            NaN       0
# 32               NaN  U01S79YDELR  1.616487e+09            NaN       0
# 33               NaN  U01RN7BVD1C  1.616487e+09    U01SJKB2MG8       0
# 34               NaN  U01RW140HBP  1.616487e+09    U01S79YDELR       0
# 35               NaN  U01RW140HBP           NaN            NaN       0
# 36               NaN  U01RW140HBP  1.616487e+09    U01S79YDELR       0
# 37               NaN  U01S79YDELR  1.616487e+09    U01S79YDELR       0
# 38               NaN  U01RW140HBP  1.616487e+09    U01S79YDELR       0
# 39               NaN  U01RW140HBP           NaN            NaN       0
# 40               NaN  U01RW2X7S9Z           NaN            NaN       0
# 42               NaN  U01S7KCL3DF  1.616494e+09            NaN       0
# 43               NaN  U01RW140HBP           NaN            NaN       0
# 44               NaN  U01S7BM4N81  1.616494e+09    U01S7KCL3DF       0
# 45               NaN  U01S7BM4N81  1.616494e+09    U01S7KCL3DF       0
# 46               NaN  U01RW140HBP  1.616494e+09    U01S7KCL3DF       0
# 47               NaN  U01RW140HBP  1.616494e+09    U01S7KCL3DF       0
# 48               NaN  U01S0E0MRJ7  1.616443e+09    U01SJKB2MG8       0
# 49               NaN  U01RW140HBP  1.616443e+09    U01SJKB2MG8       0
# 50               NaN  U01S7KCL3DF  1.616494e+09    U01S7KCL3DF       0
# 51               NaN  U01SJKB2MG8  1.616443e+09    U01SJKB2MG8       0
# 55               NaN  U01RW140HBP  1.616494e+09    U01S7KCL3DF       0
# 56               NaN  U01RW140HBP  1.616494e+09    U01S7KCL3DF       0
# 58               NaN  U01RW140HBP  1.616494e+09    U01S7KCL3DF       0
# 59               NaN  U01S7KCL3DF  1.616494e+09    U01S7KCL3DF       0
# 60               NaN  U01RXCQHMHT  1.616512e+09            NaN       0
# 61               NaN  U01RW140HBP  1.616512e+09    U01RXCQHMHT       0
# 62               NaN  U01RN7BVD1C           NaN            NaN       0
# 63               NaN  U01RS9Y6UJH  1.616512e+09            NaN       0
# 64               NaN  U01RW140HBP  1.616512e+09    U01RS9Y6UJH       0
#
#     polarity
# 0   0.500000
# 1   0.000000
# 2   0.000000
# 3   0.000000
# 4   0.000000
# 5   0.000000
# 6   0.000000
# 7   0.350000
# 8   0.250000
# 9   0.000000
# 10  0.000000
# 11  0.000000
# 12 -0.250000
# 13  0.000000
# 14  0.000000
# 15  0.000000
# 16 -0.350000
# 17 -0.250000
# 18  0.000000
# 19  0.000000
# 20  0.000000
# 21  0.000000
# 22  0.000000
# 23  0.000000
# 24  0.200000
# 25  0.000000
# 26  0.000000
# 27 -0.400000
# 28  0.200000
# 29  0.000000
# 30  0.000000
# 31  0.000000
# 32  0.000000
# 33  0.200000
# 34  0.357143
# 35  0.000000
# 36 -0.175000
# 37  0.400000
# 38  0.300000
# 39  0.000000
# 40  0.000000
# 42  0.339683
# 43  0.000000
# 44  0.000000
# 45  0.000000
# 46  0.233333
# 47  0.000000
# 48  0.000000
# 49  0.000000
# 50  0.300000
# 51  0.166667
# 55  0.375000
# 56  0.350000
# 58 -0.050000
# 59  0.283333
# 60  0.000000
# 61  0.250000
# 62  0.250000
# 63  0.200000
# 64  0.000000

# %%
sns.histplot(df['polarity'])
# Out:
# <AxesSubplot:xlabel='polarity', ylabel='Count'>

# %%
PR = []
for i in df['polarity']:
    if i > 0.49:
        PR.append('Positive')
    elif i > 0:
        PR.append('Neutral')
    elif i == 0:
        PR.append('Na')
    else:
        PR.append('Negative')

# %%
df['p_rating'] = PR
df
# Out:
#                  time   name  \
# 0    21/03/2021 17:04  siand
# 1    23/03/2021 07:02    NaN
# 2    23/03/2021 07:26    NaN
# 3    23/03/2021 07:41    NaN
# 4    23/03/2021 07:42    NaN
# ..                ...    ...
# 625  27/04/2021 10:40    NaN
# 626  27/04/2021 10:40  siand
# 627  27/04/2021 10:40  siand
# 628  27/04/2021 10:41  siand
# 629  27/04/2021 10:42  siand
#
#                                                   text  subtype  num_reply  \
# 0                     hi everyone! see you tomorrow :)      NaN        NaN
# 1                                                 same      NaN        NaN
# 2    same, can you give access to <mailto:andreatog...      NaN        NaN
# 3    my address is <mailto:karina.condeixa@gmail.co...      NaN        NaN
# 4    Letâ€™s try using Slack forâ€¦how do we join z...      NaN        3.0
# ..                                                 ...      ...        ...
# 625  just to warn you though, the whole zip file of...      NaN        NaN
# 626  because it contains text files with the links,...      NaN        NaN
# 627         but yes i am sure you guys can wrangle it!      NaN        NaN
# 628                  just your average 200 mb file lol      NaN        NaN
# 629  ok so we think we have a plan for the notion c...      NaN        NaN
#
#      num_participants         user      thred_ts parent_user_id  thanks  \
# 0                 NaN  U01RW140HBP           NaN            NaN       0
# 1                 NaN  U01S0MFJ3HR  1.616443e+09    U01SJKB2MG8       0
# 2                 NaN  U01SD3CDH9P  1.616443e+09    U01SJKB2MG8       0
# 3                 NaN  U01S79YDELR  1.616443e+09    U01SJKB2MG8       0
# 4                 NaN  U01RS9Y6UJH  1.616485e+09            NaN       0
# ..                ...          ...           ...            ...     ...
# 625               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 626               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 627               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 628               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 629               NaN  U01RW140HBP           NaN            NaN       0
#
#      polarity  p_rating
# 0       0.500  Positive
# 1       0.000        Na
# 2       0.000        Na
# 3       0.000        Na
# 4       0.000        Na
# ..        ...       ...
# 625     0.200   Neutral
# 626     0.000        Na
# 627     0.625  Positive
# 628     0.325   Neutral
# 629     0.145   Neutral
#
# [597 rows x 12 columns]

# %% [markdown]
# ## A sentiment rating per user

# %%
user_polrate = df.groupby(['user']).polarity.min()

# %%
user_polrate
# Out:
# user
# U01RKN0EGDV   -0.312500
# U01RN7BVD1C   -0.370833
# U01RP2K1606    0.000000
# U01RRV4JX6Z   -1.000000
# U01RS9Y6UJH   -0.150000
# U01RSRE0N3D   -0.500000
# U01RUTP1ZQB   -0.300000
# U01RUU9SK4K    0.150000
# U01RV3K524T    0.075000
# U01RW140HBP   -0.500000
# U01RW2X7S9Z   -0.625000
# U01RXCQHMHT   -0.400000
# U01S081EULS    0.000000
# U01S0E0MRJ7    0.000000
# U01S0MFJ3HR    0.000000
# U01S0P26NKD   -0.166667
# U01S133DZ9A   -0.456250
# U01S65G72SY    0.000000
# U01S6L7HLUC    0.000000
# U01S6LCPM0C    0.400000
# U01S79YDELR   -0.500000
# U01S7BM4N81   -0.500000
# U01S7KCL3DF   -0.750000
# U01SD3CDH9P   -0.750000
# U01SJKB2MG8   -0.400000
# U01SK96QF5E   -0.045833
# Name: polarity, dtype: float64

# %%
user_polrate.to_csv('user_polrate.csv')

# %% [markdown]
# Maybe if you can group the conversations. You can apply this to get the sentiment ranking per conversation ?

# %% [markdown]
# ## 5. Extract emoji to new column

# %%
import numpy as np
df['emo']=df['text'].str.extract(r'\:(.*?)\:')

# %%
df.head(50)
# Out:
#                 time       name  \
# 0   21/03/2021 17:04      siand
# 1   23/03/2021 07:02        NaN
# 2   23/03/2021 07:26        NaN
# 3   23/03/2021 07:41        NaN
# 4   23/03/2021 07:42        NaN
# 5   23/03/2021 07:42      Thamo
# 6   23/03/2021 07:42        NaN
# 7   23/03/2021 07:43        NaN
# 8   23/03/2021 07:44        NaN
# 9   23/03/2021 07:44      Thamo
# 10  23/03/2021 07:49        NaN
# 11  23/03/2021 07:50        NaN
# 12  23/03/2021 08:00        Sam
# 13  23/03/2021 08:00        NaN
# 14  23/03/2021 08:01  Alexandre
# 15  23/03/2021 08:01  Alexandre
# 16  23/03/2021 08:01        Sam
# 17  23/03/2021 08:01      Thamo
# 18  23/03/2021 08:02        NaN
# 19  23/03/2021 08:02      siand
# 20  23/03/2021 08:02  Alexandre
# 21  23/03/2021 08:03        NaN
# 22  23/03/2021 08:03    Florian
# 23  23/03/2021 08:04        NaN
# 24  23/03/2021 08:04        NaN
# 25  23/03/2021 08:05        NaN
# 26  23/03/2021 08:05        NaN
# 27  23/03/2021 08:10    Florian
# 28  23/03/2021 08:10        NaN
# 29  23/03/2021 08:10        NaN
# 30  23/03/2021 08:11        NaN
# 31  23/03/2021 08:13      Thanh
# 32  23/03/2021 08:13        NaN
# 33  23/03/2021 08:13  Josephine
# 34  23/03/2021 08:13      siand
# 35  23/03/2021 08:13      siand
# 36  23/03/2021 08:15      siand
# 37  23/03/2021 08:16        NaN
# 38  23/03/2021 08:27      siand
# 39  23/03/2021 08:42      siand
# 40  23/03/2021 08:49        NaN
# 42  23/03/2021 10:09        Sam
# 43  23/03/2021 10:09      siand
# 44  23/03/2021 10:10      Thamo
# 45  23/03/2021 10:11      Thamo
# 46  23/03/2021 10:14      siand
# 47  23/03/2021 10:14        NaN
# 48  23/03/2021 10:18        NaN
# 49  23/03/2021 10:21      siand
# 50  23/03/2021 10:22        NaN
#
#                                                  text  subtype  num_reply  \
# 0                    hi everyone! see you tomorrow :)      NaN        NaN
# 1                                                same      NaN        NaN
# 2   same, can you give access to <mailto:andreatog...      NaN        NaN
# 3   my address is <mailto:karina.condeixa@gmail.co...      NaN        NaN
# 4   Letâ€™s try using Slack forâ€¦how do we join z...      NaN        3.0
# 5   Same link as yesterday, the message is pinned ...      NaN        NaN
# 6                     I believe that is the same link      NaN        NaN
# 7                                           ok thanks      NaN        NaN
# 8                                       Thanks Thamo!      NaN        NaN
# 9                                         :v:welcome       NaN        NaN
# 10                                            morning      NaN        NaN
# 11  my adress is: <mailto:anja.fechner@live.de|anj...      NaN        NaN
# 12  <https://ironhack.zoom.us/j/877626245?pwd=YjFt...      NaN        2.0
# 13                                 not working for me      NaN        NaN
# 14                      <https://zoom.us/j/877626245>      NaN        NaN
# 15                                          pw 986565      NaN        NaN
# 16                      this one no good? i'll delete      NaN        NaN
# 17                  seems like that but I am not sure      NaN        NaN
# 18                   shows no upcoming meetings today      NaN        NaN
# 19                                its running  Karina      NaN        NaN
# 20            did you open the link in the navigator?      NaN        NaN
# 21                         yes and then using the app      NaN        NaN
# 22  <!channel>,\ncan you access the content now? W...      NaN        1.0
# 23                                mine not signing in      NaN        NaN
# 24  yes, thanks. I have problems to go the the cla...      NaN        NaN
# 25             <@U01SJKB2MG8> i cannot join the class      NaN        NaN
# 26  could we have the user name and signing like t...      NaN        2.0
# 27  <!channel>!\nQUIZME after the coffee break!\ng...      NaN        NaN
# 28                    used another laptop. But thanks      NaN        NaN
# 29                                             Karina      NaN        NaN
# 30                              i am going to restart      NaN        NaN
# 31                                     <@U01SD3CDH9P>      NaN        NaN
# 32   yes, finaly I could enter to the zoom, the class      NaN        4.0
# 33                Yeyyyy it works :heart_eyes: Thanks      NaN        NaN
# 34  what happened? did you have to do something sp...      NaN        NaN
# 35                                     PINÂ *9973821*      NaN        NaN
# 36  so weird, normally this works fineâ€¦ just go ...      NaN        NaN
# 37                thanks, it finally worked for me :D      NaN        NaN
# 38      maybe worth clearing the cache or something ?      NaN        NaN
# 39  notion link <https://www.notion.so/ironhack/Be...      NaN        NaN
# 40          it doesnt show up the docx file attached?      NaN        NaN
# 42  On histograms in Excel....I thought State woul...      NaN       10.0
# 43  tip of the day : <https://statistics.laerd.com...      NaN        NaN
# 44                               Just one column, yes      NaN        NaN
# 45                      Try another type of histogram      NaN        NaN
# 46  I would use a pivot table to sum up how many r...      NaN        NaN
# 47                                               eg :      NaN        NaN
# 48  How can I open the solution code? Can I import...      NaN        NaN
# 49                         <@U01SJKB2MG8> one for you      NaN        NaN
# 50           column chart gives me this peach :smile:      NaN        NaN
#
#     num_participants         user      thred_ts parent_user_id  thanks  \
# 0                NaN  U01RW140HBP           NaN            NaN       0
# 1                NaN  U01S0MFJ3HR  1.616443e+09    U01SJKB2MG8       0
# 2                NaN  U01SD3CDH9P  1.616443e+09    U01SJKB2MG8       0
# 3                NaN  U01S79YDELR  1.616443e+09    U01SJKB2MG8       0
# 4                NaN  U01RS9Y6UJH  1.616485e+09            NaN       0
# 5                NaN  U01S7BM4N81  1.616485e+09    U01RS9Y6UJH       0
# 6                NaN  U01S79YDELR  1.616485e+09    U01RS9Y6UJH       0
# 7                NaN  U01RS9Y6UJH  1.616485e+09    U01RS9Y6UJH       0
# 8                NaN  U01S79YDELR           NaN            NaN       0
# 9                NaN  U01S7BM4N81           NaN            NaN       0
# 10               NaN  U01RW2X7S9Z           NaN            NaN       0
# 11               NaN  U01S0MFJ3HR  1.616443e+09    U01SJKB2MG8       0
# 12               NaN  U01S7KCL3DF  1.616486e+09            NaN       0
# 13               NaN  U01S79YDELR           NaN            NaN       0
# 14               NaN  U01RW2X7S9Z           NaN            NaN       0
# 15               NaN  U01RW2X7S9Z           NaN            NaN       0
# 16               NaN  U01S7KCL3DF  1.616486e+09    U01S7KCL3DF       0
# 17               NaN  U01S7BM4N81  1.616486e+09    U01S7KCL3DF       0
# 18               NaN  U01S79YDELR           NaN            NaN       0
# 19               NaN  U01RW140HBP           NaN            NaN       0
# 20               NaN  U01RW2X7S9Z           NaN            NaN       0
# 21               NaN  U01S79YDELR           NaN            NaN       0
# 22               NaN  U01SJKB2MG8  1.616487e+09            NaN       0
# 23               NaN  U01S0P26NKD           NaN            NaN       0
# 24               NaN  U01S79YDELR           NaN            NaN       0
# 25               NaN  U01S79YDELR           NaN            NaN       0
# 26               NaN  U01S0P26NKD  1.616487e+09            NaN       0
# 27               NaN  U01SJKB2MG8           NaN            NaN       0
# 28               NaN  U01S0P26NKD           NaN            NaN       0
# 29               NaN  U01S79YDELR  1.616487e+09    U01S0P26NKD       0
# 30               NaN  U01S79YDELR  1.616487e+09    U01S0P26NKD       0
# 31               NaN  U01RXCQHMHT           NaN            NaN       0
# 32               NaN  U01S79YDELR  1.616487e+09            NaN       0
# 33               NaN  U01RN7BVD1C  1.616487e+09    U01SJKB2MG8       0
# 34               NaN  U01RW140HBP  1.616487e+09    U01S79YDELR       0
# 35               NaN  U01RW140HBP           NaN            NaN       0
# 36               NaN  U01RW140HBP  1.616487e+09    U01S79YDELR       0
# 37               NaN  U01S79YDELR  1.616487e+09    U01S79YDELR       0
# 38               NaN  U01RW140HBP  1.616487e+09    U01S79YDELR       0
# 39               NaN  U01RW140HBP           NaN            NaN       0
# 40               NaN  U01RW2X7S9Z           NaN            NaN       0
# 42               NaN  U01S7KCL3DF  1.616494e+09            NaN       0
# 43               NaN  U01RW140HBP           NaN            NaN       0
# 44               NaN  U01S7BM4N81  1.616494e+09    U01S7KCL3DF       0
# 45               NaN  U01S7BM4N81  1.616494e+09    U01S7KCL3DF       0
# 46               NaN  U01RW140HBP  1.616494e+09    U01S7KCL3DF       0
# 47               NaN  U01RW140HBP  1.616494e+09    U01S7KCL3DF       0
# 48               NaN  U01S0E0MRJ7  1.616443e+09    U01SJKB2MG8       0
# 49               NaN  U01RW140HBP  1.616443e+09    U01SJKB2MG8       0
# 50               NaN  U01S7KCL3DF  1.616494e+09    U01S7KCL3DF       0
#
#     polarity  p_rating         emo
# 0   0.500000  Positive         NaN
# 1   0.000000        Na         NaN
# 2   0.000000        Na         NaN
# 3   0.000000        Na         NaN
# 4   0.000000        Na         NaN
# 5   0.000000        Na         NaN
# 6   0.000000        Na         NaN
# 7   0.350000   Neutral         NaN
# 8   0.250000   Neutral         NaN
# 9   0.000000        Na           v
# 10  0.000000        Na         NaN
# 11  0.000000        Na     <mailto
# 12 -0.250000  Negative         NaN
# 13  0.000000        Na         NaN
# 14  0.000000        Na         NaN
# 15  0.000000        Na         NaN
# 16 -0.350000  Negative         NaN
# 17 -0.250000  Negative         NaN
# 18  0.000000        Na         NaN
# 19  0.000000        Na         NaN
# 20  0.000000        Na         NaN
# 21  0.000000        Na         NaN
# 22  0.000000        Na         NaN
# 23  0.000000        Na         NaN
# 24  0.200000   Neutral         NaN
# 25  0.000000        Na         NaN
# 26  0.000000        Na         NaN
# 27 -0.400000  Negative         NaN
# 28  0.200000   Neutral         NaN
# 29  0.000000        Na         NaN
# 30  0.000000        Na         NaN
# 31  0.000000        Na         NaN
# 32  0.000000        Na         NaN
# 33  0.200000   Neutral  heart_eyes
# 34  0.357143   Neutral         NaN
# 35  0.000000        Na         NaN
# 36 -0.175000  Negative         NaN
# 37  0.400000   Neutral         NaN
# 38  0.300000   Neutral         NaN
# 39  0.000000        Na         NaN
# 40  0.000000        Na         NaN
# 42  0.339683   Neutral       smile
# 43  0.000000        Na      <https
# 44  0.000000        Na         NaN
# 45  0.000000        Na         NaN
# 46  0.233333   Neutral         NaN
# 47  0.000000        Na         NaN
# 48  0.000000        Na         NaN
# 49  0.000000        Na         NaN
# 50  0.300000   Neutral       smile

# %% [markdown]
# ## 6. Count  questions

# %%
Qu = []
Qcount = 0

# %%
for a in df['text']:
    x = re.search('\?', a)
    if x is None:
        Qu.append('no')
    else:
        Qu.append(a)
        Qcount += 1

# %%
Qcount
# Out:
# 132

# %%
Qu
# Out:
# ['no',
#  'no',
#  'same, can you give access to <mailto:andreatognoli001@gmail.com|andreatognoli001@gmail.com>, pls?',
#  'no',
#  'Letâ€™s try using Slack forâ€¦how do we join zoom today (and every morning) will a link be posted here?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<https://ironhack.zoom.us/j/877626245?pwd=YjFtWlpiNHRDZzg4K0J5dWVKcHIzZz09>\n\nPinning this meeting link with the password as I am _that_ lazy',
#  'no',
#  'no',
#  'no',
#  "this one no good? i'll delete",
#  'no',
#  'no',
#  'no',
#  'did you open the link in the navigator?',
#  'no',
#  '<!channel>,\ncan you access the content now? We changed permissions\n<https://data-ft-ber-03-2021.slack.com/archives/C01RKRMS10W/p1616443201022100>',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'what happened? did you have to do something special',
#  'no',
#  'no',
#  'no',
#  'maybe worth clearing the cache or something ?',
#  'no',
#  'it doesnt show up the docx file attached?',
#  "On histograms in Excel....I thought State would be an easy one as a lot of them match, but Excel doesn't give me Histogram as a recommended chart type :smile:\n\nis there any trick to it? I just need to apply it to one column right?",
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'How can I open the solution code? Can I import it in Jupyter notebook somehow?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<!everyone> This is a good tutorial on Git and Github if you have some problems :slightly_smiling_face:\n\n<https://www.youtube.com/watch?v=RGOj5yH7evk>',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  "wait.... you're saying your machine is not connected with a photonic fiber to the internet? no HFT for you then :grin:\n<https://www.laserfocusworld.com/fiber-optics/article/14183435/hollowcore-fiber-gives-highfrequency-traders-an-edge>",
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<https://www.youtube.com/watch?v=d8BcCLLX4N4>',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'is that data looking at marketed prices or actual selling/renting prices?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  "<!channel>,\nRegarding the upcoming Lab `Customer Analysis Round 3` : I inspected it and reworked the instructions. Please take the same data, but take these instructions:\n\n&gt; For this lab, we still keep using the `marketing_customer_analysis.csv` file. You can find the file in the `files_for_lab` folder.\n&gt; \n&gt; *Get the data*\n&gt; Use the same jupyter file from the last lab, `Customer Analysis Round 3`\n&gt; \n&gt; *EDA (Exploratory Data Analysis) - Complete the following tasks to explore the data:*\n&gt; * Show DataFrame info.\n&gt; * Describe DataFrame.\n&gt; * Show a plot of the total number of `response`s broken down by response kind.\n&gt; * Show a plot of the ~response rate~ number of `response`s by the `sales channel`.\n&gt; * ~Show a plot of the response rate by the total claim amount.~ Show a plot of the distribution of the `total claim amount`, broken down by `response` kind. Try a boxplot and distribution plot, for each `response` kind. For the distribution plot, try to plot both kinds of responses in one chart (you can try with seaborn's histplot, using the `hue` parameter).\n&gt; * ~Show a plot of the response rate by income.~ Create similar plots like in the task before, but for `Income`\n&gt; * *NEW*: Create a scatterplot between `total claim amount` and `income`. Play around with the parameters of the scatterplot (markersize? alpha?) and try to identify more features within the data just visually. You can also try different seaborn plots. Check to find suitable ones: <https://www.python-graph-gallery.com/134-how-to-avoid-overplotting-with-python>",
#  'Hey, so Im still not getting how to get my data from Git hub into Jupyter, clone then pull..anybody else still having problems with this? maybe a TA could walk me through it',
#  'no',
#  'no',
#  '* Show a plot of theÂ\xa0~response rate~Â\xa0number ofÂ\xa0`response`s by theÂ\xa0`sales channel`.\n\nis only the response="yes" that count as response? or is either response=yes, no a response?',
#  'no',
#  'no',
#  'no',
#  'me too... but watching the GitHub link that Tony shared is on my to do list:\n\n<https://www.youtube.com/watch?v=RGOj5yH7evk>',
#  'no',
#  'no',
#  'for this:\n\n&gt; Show a plot of the distribution of theÂ\xa0`total claim amount`, broken down byÂ\xa0`response`Â\xa0kind.\ntrying to use\n`sns.boxplot(x = \'Response\',y = \'total_claim_amount\', file1=file1)`\n`plt.show()`\n\nbut I always get errors for the column names:\n\n"Could not interpret input \'Response\'" :thinking_face:  ... did I not install Seaborn properly?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'Do you have any idea why?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  "So what's the point?",
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  "if we've made multiple errors on the work do we still upload them? asking for a friend",
#  'ah got itâ€¦ but it still isnt a shell function right?',
#  "Well, I'm new to this. Is what i wrote a script?",
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'What is the purpose of functions in Data Analytics? To test models, for example?',
#  'A linear regression?',
#  "ooh good questionâ€¦. functions are effectively used to do tasks either repeatedly or robustly (applying rules, arguments, transformations)â€¦ you may remember in class that we wrote a clean function to tidy up the gender column, but theres a tonne of ways we could use a function in a data analysis process, from cleaning, through EDA, to predictive modelling. heres a cool example of a function you can use right now\ndef histograms_numeric_columns(df, numerical_columns):\n    â€˜â€™'\n    Takes df, numerical columns as list\n    Returns a grid of histograms\n    â€˜â€™'\n    f = pd.melt(df, value_vars=numerical_columns)\n    g = sns.FacetGrid(f, col=â€˜variableâ€™,  col_wrap=4, sharex=False, sharey=False)\n    g = g.map(sns.distplot, â€˜valueâ€™)\n    return g\nâ€¦.this is a time saver functionâ€¦. instead of making a bunch of separate histograms, return all your columns as a grid of histograms. we can look at this in the morning if you like ?",
#  'no',
#  'no',
#  '<!channel>,\n:microscope: Lab solutions are online, find them <https://www.notion.so/ironhack/2b2030e11f5641819fa5de6aa86d176e?v=dcb0378d46404b02990e1b67ae88666c|on notion> or directly on <https://github.com/student-IH-labs-and-stuff/BER-DAFT-MAR21/blob/main/Solutions/unit1/day4/customer_analysis_round_3_solution.ipynb|github>. *PLOT ON* :grin:',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<https://www.bing.com/videos/search?q=how+to+push+file+from+jupiter+notebook+to+git+hub+using+git+bash&amp;qpvt=how+to+push+file+from+jupiter+notebook+to+git+hub+using+git+bash&amp;view=detail&amp;mid=4AA151373665F94434F14AA151373665F94434F1&amp;&amp;FORM=VRDGAR&amp;ru=%2Fvideos%2Fsearch%3Fq%3Dhow%2Bto%2Bpush%2Bfile%2Bfrom%2Bjupiter%2Bnotebook%2Bto%2Bgit%2Bhub%2Busing%2Bgit%2Bbash%26qpvt%3Dhow%2Bto%2Bpush%2Bfile%2Bfrom%2Bjupiter%2Bnotebook%2Bto%2Bgit%2Bhub%2Busing%2Bgit%2Bbash%26FORM%3DVDRE|https://www.bing.com/videos/search?q=how+to+push+file+from+jupiter+notebook+to+git+[â€¦]2Bnotebook%2Bto%2Bgit%2Bhub%2Busing%2Bgit%2Bbash%26FORM%3DVDRE>',
#  'no',
#  'Could you download this file Sian is working on? I did not find',
#  'no',
#  'What am I doing wrong?',
#  'no',
#  'no',
#  'could you please send me a shot, a picture of the firsts commands she made?',
#  'no',
#  'you mean this?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<@U01S6L7HLUC> and others, here is a 10 min screen record if you want to follow the steps at your own pace of how to push work to your github repo and submit lab work via the student portal <https://drive.google.com/file/d/18Ov6BZJLGqbAmZmr_awvywBPRgNRviee/view?usp=sharing>',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<@U01S133DZ9A> something like that?',
#  'no',
#  'no',
#  'Any ideas?',
#  'i think null values are NaN already?',
#  'no',
#  'you can turn zeroes into null values, but i think NaN is same as null ?',
#  'no',
#  'Is this a question or are they asking us to make them look like a normal distribution?',
#  'no',
#  'no',
#  "Hey Alex. Thanks for coming back. At the moment the auto-insurance customer data has '0' (int) as by far the most common entry - this skews the data badly when we are looking at correlations.\nWe did get shown how to turn null values into mean value - but this is still not ideal in this case. Would be better to just discount the null values from the income column - (by calling them NaN ?)",
#  'no',
#  'task on BI tools\n*Your task (individual or in pairs):*Â\xa0Â\xa0\nPick one of the BI tools we have discussed today\nReview one of the business case studies from their website (or another you find with the help of your friend google!)Â\xa0\nSummarise the overall business objective(s)Â\xa0\nSee if you can identify specific steps taken with the software /consulting services/ training/ organisational change to fulfil the companyâ€™s objectivesÂ\xa0\nIs a timeline mentioned?',
#  'no',
#  'what are the mistakes often made by organisation in adopting data visualisation tools &amp; techniques\nwhat does David suggest could be done differently?',
#  'no',
#  '<!channel> Hey everyone :slightly_smiling_face:\n\nI just wanted to reach out to you again about the mystery room event on Friday, if you havent already filled out the survey, please do so today to let me know if you are interested in joining the event. Please let me know before 3 PM today so I can book out the rooms :)\n\n_"We here at Ironhack wouldÂ\xa0like to invite all our students to a special online exit roomÂ\xa0event next Friday at 19.00._\n_This is a great way to get in contact with studentsÂ\xa0from other courses._\n_During the event you will be split into small group and through the use of a camera you will steer a real life gamester through a series off puzzles. We did this event last bootcamp and it was alot of fun, some students had to protect the world against a deadly zombie virus while others had to defuse an atomic bom!!_\n_If this sounds like something you would be interested in please let us know by filling out thisÂ\xa0<https://ironhack-dot-yamm-track.appspot.com/Redirect?ukey=1lXsSGMtJ2C_SRHOCRp9C47W8sjM-aaI6CM0TUwUmV44-286680014&amp;key=YAMMID-04245215&amp;link=https%3A%2F%2Fironhack.typeform.com%2Fto%2FMbnfwBkS|survey>."_\n_BTW. staff is welcome ;)_\n\nKind regards\nThe PM Team\n\nJonas',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<!channel> Hi Ironhackers :slightly_smiling_face:\n\nDont forget that we have the yoga classes twice a week at 12.30 on Tuesdays and 18.00 on Thursdays :slightly_smiling_face:\nHere is the link:\n<https://us02web.zoom.us/j/82711867834?pwd=cWVFSXdVUEh5V2s1YVVxMDJxSi9UUT09>',
#  'no',
#  'no',
#  'i thought the room was always open? the class room?',
#  'no',
#  'no',
#  'Someone has to host the zoom, right?',
#  'no',
#  'no',
#  '<!here> EASTER FUN - at 5pm today we will have a quick easter get together online to celebrate that we all worked a day when no-one else did :slightly_smiling_face: Attendance is optional for all the fun activities but if you do want to join us in the zoom classroom here are some things to prepare :\nâ€¢ do bring your children/ pets / housemates / partners \nâ€¢ do you have some chocolate or a chocolate egg in the house ? if yes, bring it to the zoom! \nâ€¢ using either a small toy or a brightly coloured egg - hide it somewhere in a room in the house- it should be just visible - take a photo of the room, ready to share - we will go for a virtual easter egg hunt \nâ€¢ if you have any arts and craft materials, paper/ pencils / pens - make sure you have them within your reach ',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'is the easter egg hunt on the general zoom or in some breakout room or a little bit later? :slightly_smiling_face:',
#  'no',
#  'no',
#  '<https://open.spotify.com/track/0wvIGFIgbyz4JNwQhZgTv2?si=goFuUsNdQuGPqKQ_6liTng>\n\nRooster impression',
#  '<https://www.youtube.com/watch?v=A43JOxLa5MM>',
#  'no',
#  'does anyone have a work agency Gutschein?I have question about a letter I received, because I donâ€™t speak German. Could someone help me please?',
#  'the bildungsgutschein? my german sucks but i can have a go sure :smile:',
#  'no',
#  'no',
#  'Amazing statistic and visualization... <https://www.washingtonpost.com/weather/2021/03/29/japan-kyoto-cherry-blossoms-record/?fbclid=IwAR0tl2CXCiQdcWkMpW7DdLFTnWI526uhKuCB1ZLWQSlxmjKmytqn9j5f9G4|https://www.washingtonpost.com/weather/2021/03/29/japan-kyoto-cherry-blossoms-record/?fb[â€¦]0tl2CXCiQdcWkMpW7DdLFTnWI526uhKuCB1ZLWQSlxmjKmytqn9j5f9G4>',
#  'Are yesterdays recordings gonna be online soon? :grimacing: <@U01RSRE0N3D> <@U01SJKB2MG8> ',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'Hey <@U01S65G72SY> do you know where in general the recordings are? :see_no_evil:\n\ne.g. <https://www.notion.so/d069723dff344c84a2671d31010d3c11?v=e92549911eb9432ba98ede76c4e86042&amp;p=cd347c74ccf64fa49d4be5ccbffed42a|Python fundamentals>?',
#  'ahhh sorry now I see everything is in a separate place\n\n<https://www.notion.so/a19c60daecc2460396bfd3e2f32ccd34?v=c9cfed266f074df580579b93192d0b96>',
#  'Should be here: <https://www.notion.so/a19c60daecc2460396bfd3e2f32ccd34?v=c9cfed266f074df580579b93192d0b96>',
#  'Do you guys know if the recording of Friday 1st of April class is already on Notion?',
#  'no',
#  '<@U01SJKB2MG8>, <@U01RSRE0N3D>: Can you guys estimate when the solutions to the ML Lab will be on notion? Or will there be a model solution at all?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<!channel> quick quâ€¦ has everyone done the weekly survey from friday ??',
#  'no',
#  'no',
#  'Any news about 2nd of April recording? Also the 5th of April recording would be great :slightly_smiling_face:',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<!channel>,\n :microscope: *regarding the today\'s labs (after lecture/lunch)*\nplease stick to these "improved" instructions (and not the ones you find under the github link):\n\nâ€¢ *Lab | SQL Queries - Lesson 2.5*\n1. Select all the actors with the first name â€˜Scarlettâ€™.\n2. How many films (movies) are available for rent and how many films have been rented?\n3. What are the shortest and longest movie duration? Return the results as columns with the namesÂ\xa0Â\xa0`max_duration`Â\xa0andÂ\xa0`min_duration`.\n4. What\'s the average movie duration expressed in format (hours, minutes) Return the result as columns with the namesÂ\xa0`hours`Â\xa0andÂ\xa0`minutes`?\n5. How many distinct (different) actors\' last names are there?\n6. Since how many days has the company been operating (check theÂ\xa0`DATEDIFF()`Â\xa0function)? Hint: rental table\n7. Show all rental information with additional columnsÂ\xa0`month`Â\xa0andÂ\xa0`weekday`. (hint:Â\xa0`DATE_FORMAT()`Â\xa0). Get 20 results.\n8. Add an additional columnÂ\xa0`day_type`Â\xa0with valuesÂ\xa0_\'weekend\'_Â\xa0andÂ\xa0_\'workday\'_Â\xa0depending on the rental day of the week.\n9. How many rentals were made in the last month of renting activity?\n.... stay tuned, improved instructions for the other labs will maybe follow',
#  '<!channel>,\n:microscope: for *Lab | SQL Queries - Lesson 2.6*\nplease use these instructions\n\n1. Get the unique release years.\n2. Get all films with _ARMAGEDDON_ in the title.\n3. Get all films which title ends with _APOLLO_.\n4. Get 10 the longest films.\n5. How many films include *Behind the Scenes* content?\n6. Drop column `picture` from `staff`.\n7. A new person is hired to help Jon. Her name is TAMMY SANDERS, and she is a customer. Update the database accordingly.\n8. Add a rental for movie "Academy Dinosaur" by the customer "Charlotte Hunter" from employee Mike Hillyer at Store 1. You can use current date for the `rental_date` column in the `rental` table. *Hint*: Check the columns in the table rental and see what information you would need to add there. You can query those pieces of information in other tables. For eg., you would notice that you need `customer_id` information as well. To get that you can use the following query: \n```select customer_id from sakila.customer\nwhere first_name = \'CHARLOTTE\' and last_name = \'HUNTER\';```\nUse similar method to get `inventory_id`, `film_id`, and `staff_id`.\n\n9. *(Optional, you can skip this)* Delete non-active users, but first, create a _backup table_ `deleted_users` to store `customer_id`, `email`, and the `date` (use `CURDATE()` , <https://www.w3schools.com/sql/func_mysql_curdate.asp|link>) for the users that would be deleted. Follow these steps:\n    â—¦ Check if there are any non-active users\n    â—¦ Create a table _`backup table`_ as suggested\n    â—¦ Insert the non active users in the table _`backup table`_\n    â—¦ Delete the non active users from the table _`customer`_',
#  'no',
#  'no',
#  'the exercises we looked at are all here right?\n\n<https://github.com/ironhack-edu/dataV3_2.05_activities>',
#  'no',
#  'Shall we drop Tammy from customers? Or just add her to staff?\nShe can be both, technically speaking',
#  'no',
#  'how would you proceed in real life? :slightly_smiling_face: (i think you already answered yourself :grin:)',
#  'no',
#  'Anyone deleted the non active users? i think have to enable safe mode',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'Who wants to be a group? :slightly_smiling_face:',
#  'no',
#  'no',
#  'no',
#  'Room ?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<@U01RW140HBP> do we want something that applies to the whole topic (i.e. restaurants) or just one question ( question iii)?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'can you add *length(number of stops) to transpot_line?*',
#  '<https://lucid.app/lucidchart/invitations/accept/inv_b013f87a-7eb0-43e8-92bc-054550d054a5?viewport_loc=-172%2C-174%2C1843%2C887%2C0_0>',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'is this the right way to spell join? or on? ahhhhhhh',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'how many people /groups found the murderer?',
#  'no',
#  'no',
#  'no',
#  'a general q: i was trying to use LOCATE in there and it said that there is no such function. is it because its different from mysql?',
#  'no there is a LOCATE in sql and mysql, maybe its just not supported in this web version (which would be weird!)\ncan you try where value LIKE â€˜%substr%â€™ instead?\ni used LIKE with the wildcard search to track down part of a number plate',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'I feel stupid asking this question at the end of week 3, but ....\nIs downloading the entire zip file the only way to get the lab files from GitHub?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'where do I find the notebook? I cannot find it on notion:(',
#  'the LT is back online â€¦. your afternoon schedule :\nâ€¢ 2pm (optional) Kosta will be on the zoom (in a breakout room?)  to guide beginners through a few ~stringy~ function-y pythons - join if you would benefit from more time on python ~strings~  functions\nâ€¢ 2:30 meet me back in the main zoom classroom, we will talk about how to evaluate logistic regression models, overfit and class imbalance. \nâ€¢ 4pm robert will join us \nâ€¢ the remainder of the day, there are a few optional labs in the Notion to keep you entertained, or you can work on tidying up your regression model to submit it on your student portal. PLEASE everyone submit a logistic regression notebook as your lab (in whatever state) today- either the iris data set or the bank A/B prediction- not just a copy of my or Floâ€™s notebook though, create your own version with a nice structure (we can tell if you copy+paste !)  ',
#  'no',
#  'no',
#  'no',
#  'and will flo later continue/finish the guided lab we were doing together?',
#  'no',
#  'is it possible to add it to the notion calendar as well?',
#  'will we continue? :pray:',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'What (in your opinion/from your experience) is the difference in having a university degree VS doing a bootcamp for jobs in data analysis/data sciene?',
#  'Looking at the content of the bootcamp, is there anything you would suggest to further study after the bootcamp? Something essential missing what you do in your daily work?',
#  'What is/ is there a task, that you are doing every day in your work?',
#  'What did you learn, what you are rarely using?\nAny tasks you have automated over the years?',
#  'no',
#  'no',
#  'no',
#  'Regarding the German market for Data Analysts should Xing be abandoned/left aside as a networking tool?',
#  'Regarding <@U01RN7BVD1C>s second question, is diving nosedeep into ML necessary?',
#  'What about Excel in Data Science. Should it be used, or should we better "hide" that we sometimes use it?',
#  'no',
#  'no',
#  'What would your advice be to recent DA graduates, in terms of preparation for job market: start with internships / small projects or apply/focus on directly full time (unless certain years of work experience required) positions ?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'Hi guys, can someone share the link for the workshop, pls?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'What steps would he recommend to shift towards a more developer side of data, as data architect/engineer?',
#  'no',
#  'no',
#  'no',
#  'today I am feeling more than ready for some chair yoga - who is with me on that ?? :zzz:',
#  'no',
#  'you trained your cat in that yet?',
#  'no',
#  'no',
#  'no',
#  'no',
#  're KNN and K form todays lecture: I dont understand how to fit  X_test and y_test in the K-model in the function we used. It only refers to the whole array. do I have to create an array from X_test and y_test?\n\ndistortions = []\ninertias = []\nmapping1 = {}\nmapping2 = {}\nK = range(1, 10)\n\nfor k in K:\n    # Building and fitting the model\n    kmeanModel = KMeans(n_clusters=k).fit(X)\n    kmeanModel.fit(X)\n\n    distortions.append(sum(np.min(cdist(X, kmeanModel.cluster_centers_,\n                                        â€˜euclideanâ€™), axis=1)) / X.shape[0])\n    inertias.append(kmeanModel.inertia_)\n\n    mapping1[k] = sum(np.min(cdist(X, kmeanModel.cluster_centers_,\n                                   â€˜euclideanâ€™), axis=1)) / X.shape[0]\n    mapping2[k] = kmeanModel.inertia_',
#  'no',
#  'no',
#  "<!channel>,\nre: github, the :github: github lecture can be found <https://www.notion.so/ironhack/a19c60daecc2460396bfd3e2f32ccd34?v=c9cfed266f074df580579b93192d0b96|on Notion>, it's the second linked video, <https://ironhack.zoom.us/rec/play/eX0eVeWTu3kbxxXEzSVCJTHoZBowZ1XHhcKGLZdeTDONbMyXLyoIY1GGS-JoterXOnDtwagb2iUQ-lqh.sKs4u3EyzrkpU_Zl?startTime=1616418141000|here> . I would say, you guys check that first, and in case there are still open questions, you can still as me or Kosta for more in-depth git explanations",
#  'no',
#  '<!channel> what about taking a 5 min coffee break after katas and doing the weekly survey!??!! yes please!',
#  '<!channel>,\nand try this in a "how do you eat an elephant? bite by bite"-way.... so, first think of the case\n```493193  --&gt;  4 + 9 + 3 + 1 + 9 + 3 = 29```\nand only after that think about building the iteration',
#  'no',
#  'no',
#  'morning, folks. What was the Repo-sample for our project?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'really? :confused:',
#  'no',
#  'Which one?',
#  'no',
#  'no',
#  'For which of the two projects?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<https://tapas.io/episode/1694477?fbclid=IwAR28NfwxXDY-5lArH_AUS9_KZEggEEe-T7p1ICbZIPBUXY7czFOFeM2dW_Q>',
#  'no',
#  'danke! all the presentations on project tips are under the Kanban/Agile entry on Notion right?\n\n<https://www.notion.so/Berlin-data-classroom-5f8f3ff27075492b8b457677368fda2d?p=952fb66992364a2d9f006326548dfaad>',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<!channel> Dont forget the yoga class today :slightly_smiling_face:\nThe class on thursday has been canceled since our instructor is going away for the weekend, so this is only class we will have this week :slightly_smiling_face:\n\n*1. HathaÂ\xa0YogaÂ\xa0Online*Â\xa0\n*Tuesdays* \n\n12:30 pm - 1:30 pmÂ\xa0Â\xa0\n\nMeeting ID:Â\xa0827 1186 7834\nPassword: breathÂ\xa0Â\xa0\n\nLINK:\n\n<https://us02web.zoom.us/j/82711867834?pwd=cWVFSXdVUEh5V2s1YVVxMDJxSi9UUT09>',
#  'no',
#  'Could you also upload the Tableau workshop recording from today? :slightly_smiling_face:',
#  'no',
#  '<@U01SJKB2MG8> or <@U01RSRE0N3D> can you keep an eye out for when that recording has compiled?',
#  'no',
#  'no',
#  'oh, I see like it takes a long time for Zoom to get it uploaded, right?',
#  'no',
#  'no',
#  'no',
#  'no',
#  '<@U01SJKB2MG8> is the recording there now ?',
#  'the tableau recording from yesterday is now up on Notion folks <https://www.notion.so/ironhack/a19c60daecc2460396bfd3e2f32ccd34?v=c9cfed266f074df580579b93192d0b96>',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'ill go slot 1! the music is for presentation?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'could you remind us, what we are to prepare?\nHow we like the course so far. Improvement suggestions, etc?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'tempelhofer feld or tempelhof somwhere else?',
#  'no',
#  'no',
#  "Nice guys. Missed this but would be up for it next time. - how about smth tomorrow early eve after we've all finished our projects?",
#  'no',
#  'no',
#  '<!channel> I imagine DJ Flo has not yet received a full list of track choices for the project presentations - <@U01SJKB2MG8> which groups are you missing ?',
#  'no',
#  ':cactus:ouch! pretty poor show!\n\nok @everyone lets get those :notes: requests today please ! what do you want to hear before your group starts presentingâ€¦. some sweet soulful :saxophone:? some head banging rock :the_horns:? :dancer: something with a little skirt swishing ? groovy disco tunes?:man_dancing::skin-tone-2:\n\notherwise teams will be allocated DJ Floâ€™s music choicesâ€¦ which may create some unexpected results â€¦. fair warning given',
#  'no',
#  'no',
#  'Great to see some project submissions coming in ahead of the deadline! we have 5 students who have already submitted their project :heavy_check_mark:â€¦ does this mean they are chilling out in a park having a :coffee: and :doughnut: or just practicing their presentation to get it slick and smooth? :thinking_face:\nAnyway well done to everyone who either has submitted or is getting close. Looking forward to seeing all of your project Repos!',
#  'no',
#  'the presentations start at 9.30, but are we meeting before, at 9 am?',
#  'no',
#  'no',
#  'no',
#  'Is it possible we save the tasks and resources from the Ironhack calendar automatically to a to do list in Notion or, even better, at Trello?  <@U01RSRE0N3D> <@U01SJKB2MG8> <@U01RW140HBP>',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  "we start at 14:30 right? Sorry I'm not sure anymore",
#  'Yes! Can someone share here the Dataset from Kaggle for later today? THanks :slightly_smiling_face:',
#  'no',
#  'do you want the file or is the link ok?',
#  'no',
#  'is this with the modifications she made in class?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'hmmm let me think on it - could it be a good web scraping examples <@U01SJKB2MG8>?',
#  'we could create a different view of the the calendar - gallery, timeline, board, list and table are also possible. Would that help as a starter?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'If you find yourself with some downtime this afternoon <!channel>, this is probably a good week to start saving a list of your useful bookmarks from this course.\nâ€¢ Anything you wish to keep from the Notion calendar \nâ€¢ Also the <https://www.notion.so/ironhack/8af74fb0e11447e9812e816ec184b958?v=c90c2e1e8d2846f0bc25d8a9e667ff1e|additional resources page> - \nâ€¢ as you may have noticed slack is truncated after a certain number of messages so we move all the useful links to Notion for you we see on the public channels, but this doesnt cover private channels. \nâ€¢ I also cannot guarantee the Notion class calendar will be available to you for many months after the course \n(these things are not in our control!)',
#  '( i find bad news when delivered by a cute dog is better received - is it true? )',
#  'Is there an easy way to copy those notion pages as pdfâ€™s or on our on notion?',
#  'no',
#  "it's probably not possible to copy the whole Berlin data classroom into our private notion pages, right?\n\nbecause usually that option is possible",
#  'no',
#  'hmm :thinking_face: it looks like i might be able to download the whole calendar as a text file with the links we have added and ALL the documentsâ€¦as a simple solution i can give you all a copy of that file at the end of the courseâ€¦ but i fear its going to be messy to work with and quite big. - what do you think ?',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no',
#  'no']

# %%
df['questions'] = Qu

# %%
df.tail(20)
# Out:
#                  time   name  \
# 610  27/04/2021 07:45    Sam
# 611  27/04/2021 08:31    Sam
# 612  27/04/2021 08:33  siand
# 613  27/04/2021 10:29    NaN
# 614  27/04/2021 10:29  siand
# 615  27/04/2021 10:30  siand
# 616  27/04/2021 10:30  Thamo
# 617  27/04/2021 10:30  Thamo
# 618  27/04/2021 10:30  Thanh
# 619  27/04/2021 10:31  siand
# 620  27/04/2021 10:36  siand
# 621  27/04/2021 10:37  Thamo
# 622  27/04/2021 10:37  Thamo
# 623  27/04/2021 10:39    NaN
# 624  27/04/2021 10:39  siand
# 625  27/04/2021 10:40    NaN
# 626  27/04/2021 10:40  siand
# 627  27/04/2021 10:40  siand
# 628  27/04/2021 10:41  siand
# 629  27/04/2021 10:42  siand
#
#                                                   text  subtype  num_reply  \
# 610  most importantly: walking distance from home :...      NaN        NaN
# 611  <https://company.onefootball.com/jobs/data-ana...      NaN        NaN
# 612  oh the sports analysis industry is massively c...      NaN        NaN
# 613                                              sorry      NaN        NaN
# 614  If you find yourself with some downtime this a...      NaN       12.0
# 615  ( i find bad news when delivered by a cute dog...      NaN        1.0
# 616  Is there an easy way to copy those notion page...      NaN        NaN
# 617                                              defo!      NaN        NaN
# 618  it's probably not possible to copy the whole B...      NaN        NaN
# 619  not sureâ€¦ feel free to explore! i havent fou...      NaN        NaN
# 620  hmm :thinking_face: it looks like i might be a...      NaN        NaN
# 621                Yes please! :slightly_smiling_face:      NaN        NaN
# 622                         We can wrangle it :python:      NaN        NaN
# 623  example this is what the dashboard lab looks like      NaN        NaN
# 624  cool i can do that ! ill make myself a reminde...      NaN        NaN
# 625  just to warn you though, the whole zip file of...      NaN        NaN
# 626  because it contains text files with the links,...      NaN        NaN
# 627         but yes i am sure you guys can wrangle it!      NaN        NaN
# 628                  just your average 200 mb file lol      NaN        NaN
# 629  ok so we think we have a plan for the notion c...      NaN        NaN
#
#      num_participants         user      thred_ts parent_user_id  thanks  \
# 610               NaN  U01S7KCL3DF  1.619508e+09    U01RW140HBP       0
# 611               NaN  U01S7KCL3DF  1.619508e+09    U01RW140HBP       0
# 612               NaN  U01RW140HBP  1.619508e+09    U01RW140HBP       0
# 613               NaN  U01RW140HBP           NaN            NaN       0
# 614               NaN  U01RW140HBP  1.619519e+09            NaN       0
# 615               NaN  U01RW140HBP  1.619519e+09            NaN       0
# 616               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 617               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 618               NaN  U01RXCQHMHT  1.619519e+09    U01RW140HBP       0
# 619               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 620               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 621               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 622               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 623               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 624               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 625               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 626               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 627               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 628               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 629               NaN  U01RW140HBP           NaN            NaN       0
#
#      polarity  p_rating                           emo  \
# 610  0.450000   Neutral   walking distance from home
# 611 -0.416667  Negative                  disappointed
# 612  0.116667   Neutral                           NaN
# 613 -0.500000  Negative                           NaN
# 614  0.317411   Neutral                           NaN
# 615  0.162500   Neutral                           NaN
# 616  0.433333   Neutral                           NaN
# 617  0.000000        Na                           NaN
# 618  0.039286   Neutral                           NaN
# 619  0.600000  Positive                           NaN
# 620  0.100000   Neutral                 thinking_face
# 621  0.000000        Na         slightly_smiling_face
# 622  0.000000        Na                        python
# 623  0.000000        Na                           NaN
# 624  0.145833   Neutral                           NaN
# 625  0.200000   Neutral                           NaN
# 626  0.000000        Na                           NaN
# 627  0.625000  Positive                           NaN
# 628  0.325000   Neutral                           NaN
# 629  0.145000   Neutral                           NaN
#
#                                              questions
# 610                                                 no
# 611                                                 no
# 612                                                 no
# 613                                                 no
# 614  If you find yourself with some downtime this a...
# 615  ( i find bad news when delivered by a cute dog...
# 616  Is there an easy way to copy those notion page...
# 617                                                 no
# 618  it's probably not possible to copy the whole B...
# 619                                                 no
# 620  hmm :thinking_face: it looks like i might be a...
# 621                                                 no
# 622                                                 no
# 623                                                 no
# 624                                                 no
# 625                                                 no
# 626                                                 no
# 627                                                 no
# 628                                                 no
# 629                                                 no

# %%
len(Qu)
# Out:
# 597

# %% [markdown]
# ## 7. Remove stop words + symbols and noise you know of (maual addition to the stop words list)

# %%
#Copy paste a list of stop words from the internet: https://gist.github.com/sebleier/554280. + added a few I spotted at the front of the list
stop_words = ["<", ">", "< @","i", "me", "my", "myself", "we", "our", "ours", "ourselves", "you", "your", "yours", "yourself", "yourselves", "he", "him", "his", "himself", "she", "her", "hers", "herself", "it", "its", "itself", "they", "them", "their", "theirs", "themselves", "what", "which", "who", "whom", "this", "that", "these", "those", "am", "is", "are", "was", "were", "be", "been", "being", "have", "has", "had", "having", "do", "does", "did", "doing", "an", "the", "and", "but", "if", "or", "because", "as", "until", "while", "of", "at", "by", "for", "with", "about", "against", "between", "into", "through", "during", "before", "after", "above", "below", "to", "from", "up", "down", "in", "out", "on", "off", "over", "under", "again", "further", "then", "once", "here", "there", "when", "where", "why", "how", "all", "any", "both", "each", "few", "more", "most", "other", "some", "such", "no", "nor", "not", "only", "own", "same", "so", "than", "too", "very", "can", "will", "just", "don", "should", "now"]

# %%
for a in df['text']:
    [word for word in a if not word in stop_words]

# %%
df.head(5)
# Out:
#                time   name                                               text  \
# 0  21/03/2021 17:04  siand                   hi everyone! see you tomorrow :)
# 1  23/03/2021 07:02    NaN                                               same
# 2  23/03/2021 07:26    NaN  same, can you give access to <mailto:andreatog...
# 3  23/03/2021 07:41    NaN  my address is <mailto:karina.condeixa@gmail.co...
# 4  23/03/2021 07:42    NaN  Letâ€™s try using Slack forâ€¦how do we join z...
#
#    subtype  num_reply  num_participants         user      thred_ts  \
# 0      NaN        NaN               NaN  U01RW140HBP           NaN
# 1      NaN        NaN               NaN  U01S0MFJ3HR  1.616443e+09
# 2      NaN        NaN               NaN  U01SD3CDH9P  1.616443e+09
# 3      NaN        NaN               NaN  U01S79YDELR  1.616443e+09
# 4      NaN        3.0               NaN  U01RS9Y6UJH  1.616485e+09
#
#   parent_user_id  thanks  polarity  p_rating  emo  \
# 0            NaN       0       0.5  Positive  NaN
# 1    U01SJKB2MG8       0       0.0        Na  NaN
# 2    U01SJKB2MG8       0       0.0        Na  NaN
# 3    U01SJKB2MG8       0       0.0        Na  NaN
# 4            NaN       0       0.0        Na  NaN
#
#                                            questions
# 0                                                 no
# 1                                                 no
# 2  same, can you give access to <mailto:andreatog...
# 3                                                 no
# 4  Letâ€™s try using Slack forâ€¦how do we join z...

# %% [markdown]
# # 8. Repeated noun-phrases and repeated triplets by row

# %%
subject_indicators = ['Code wars',
'Linear regression',
'Lab work',
'Student portal',
'Mornings lecture',
'Breakout room',
'Survey',
'Thamo',
'Sian',
'Kosta',
'Flo',
'Smote',
'script',
'function',
'histograms',
'Lab work',
'student portal',
'submitted',
'mystery room',
'Easter egg hunt',
'Survey',
'SQL',
'films',
'mornings lecture',
'miro board',
'main room',
'student portal',
'notion calendar',
'Logisitic regression',
'weekly survey',
'breakout room',
'teaching team',
'reminder',
'Stand up',
'zoom classroom',
'presentation on',
'main room'
]

# %%
df['keyword'] = ""

# %%
for a in df['text']:
    [df['keyword'].append(word) for word in a if word in subject_indicators]

# %%
df.tail(50)
# Out:
#                  time       name  \
# 579  26/04/2021 06:54        NaN
# 580  26/04/2021 06:54      Thanh
# 581  26/04/2021 06:56        NaN
# 582  26/04/2021 07:15        Sam
# 583  26/04/2021 07:37      siand
# 584  26/04/2021 08:04        NaN
# 585  26/04/2021 12:00  Josephine
# 586  26/04/2021 12:09        NaN
# 587  26/04/2021 12:11        NaN
# 588  26/04/2021 12:12        NaN
# 589  26/04/2021 12:15        NaN
# 590  26/04/2021 12:17        NaN
# 591  26/04/2021 12:19        NaN
# 593  26/04/2021 12:26        NaN
# 594  26/04/2021 14:10      siand
# 595  26/04/2021 15:03      Lilla
# 596  26/04/2021 15:03      Thanh
# 597  26/04/2021 15:07      siand
# 598  26/04/2021 15:10    Florian
# 599  26/04/2021 15:11      siand
# 600  26/04/2021 15:13    Florian
# 601  26/04/2021 15:28      siand
# 602  26/04/2021 15:31      siand
# 603  26/04/2021 15:44        NaN
# 604  26/04/2021 16:34        Sam
# 605  26/04/2021 16:50      siand
# 606  27/04/2021 07:14      siand
# 607  27/04/2021 07:25      siand
# 608  27/04/2021 07:38        Sam
# 609  27/04/2021 07:41      siand
# 610  27/04/2021 07:45        Sam
# 611  27/04/2021 08:31        Sam
# 612  27/04/2021 08:33      siand
# 613  27/04/2021 10:29        NaN
# 614  27/04/2021 10:29      siand
# 615  27/04/2021 10:30      siand
# 616  27/04/2021 10:30      Thamo
# 617  27/04/2021 10:30      Thamo
# 618  27/04/2021 10:30      Thanh
# 619  27/04/2021 10:31      siand
# 620  27/04/2021 10:36      siand
# 621  27/04/2021 10:37      Thamo
# 622  27/04/2021 10:37      Thamo
# 623  27/04/2021 10:39        NaN
# 624  27/04/2021 10:39      siand
# 625  27/04/2021 10:40        NaN
# 626  27/04/2021 10:40      siand
# 627  27/04/2021 10:40      siand
# 628  27/04/2021 10:41      siand
# 629  27/04/2021 10:42      siand
#
#                                                   text  subtype  num_reply  \
# 579         I missed that, but I want to go next time.      NaN        NaN
# 580        Yes, it was so pleasant to meet all of you!      NaN        NaN
# 581  I think the idea is to give more notice next t...      NaN        NaN
# 582  as long weâ€™re all in some polyamorous relati...      NaN        NaN
# 583  ironhack does not condone corona restriction r...      NaN        NaN
# 584                                           this one      NaN        3.0
# 585  we start at 14:30 right? Sorry I'm not sure an...      NaN        NaN
# 586  Yes! Can someone share here the Dataset from K...      NaN        4.0
# 587    <https://www.kaggle.com/carrie1/ecommerce-data>      NaN        NaN
# 588            do you want the file or is the link ok?      NaN        NaN
# 589  Thank you <@U01S79YDELR> :slightly_smiling_fac...      NaN        NaN
# 590  is this with the modifications she made in class?      NaN        NaN
# 591                 uploading. slowly.. <@U01S081EULS>      NaN        NaN
# 593  <!channel> Hey Class :slightly_smiling_face:\n...      NaN        NaN
# 594  i have published my class workbook from today ...      NaN        NaN
# 595                               it would be awesome!      NaN        NaN
# 596  no, i don't think this is the modified version...      NaN        NaN
# 597  hmmm let me think on it - could it be a good w...      NaN        NaN
# 598  we could create a different view of the the ca...      NaN        NaN
# 599  yes i think so - list is probably a good one t...      NaN        NaN
# 600                 ok, Table and List views are added      NaN        NaN
# 601                                            lovely!      NaN        NaN
# 602  it seems Notion havent finished making their a...      NaN        NaN
# 603                         ok :slightly_smiling_face:      NaN        NaN
# 604  <https://www.berliner-zeitung.de/en/snow-and-s...      NaN        NaN
# 605                                             brrrrr      NaN        NaN
# 606  todays *job inspirations* - from Dyson enginee...      NaN        NaN
# 607  and from the other end of the spectrum - anoth...      NaN        5.0
# 608  I was eyeing up a couple of jobs at HomeToGo i...      NaN        NaN
# 609  looks like a fun company - bound to have good ...      NaN        NaN
# 610  most importantly: walking distance from home :...      NaN        NaN
# 611  <https://company.onefootball.com/jobs/data-ana...      NaN        NaN
# 612  oh the sports analysis industry is massively c...      NaN        NaN
# 613                                              sorry      NaN        NaN
# 614  If you find yourself with some downtime this a...      NaN       12.0
# 615  ( i find bad news when delivered by a cute dog...      NaN        1.0
# 616  Is there an easy way to copy those notion page...      NaN        NaN
# 617                                              defo!      NaN        NaN
# 618  it's probably not possible to copy the whole B...      NaN        NaN
# 619  not sureâ€¦ feel free to explore! i havent fou...      NaN        NaN
# 620  hmm :thinking_face: it looks like i might be a...      NaN        NaN
# 621                Yes please! :slightly_smiling_face:      NaN        NaN
# 622                         We can wrangle it :python:      NaN        NaN
# 623  example this is what the dashboard lab looks like      NaN        NaN
# 624  cool i can do that ! ill make myself a reminde...      NaN        NaN
# 625  just to warn you though, the whole zip file of...      NaN        NaN
# 626  because it contains text files with the links,...      NaN        NaN
# 627         but yes i am sure you guys can wrangle it!      NaN        NaN
# 628                  just your average 200 mb file lol      NaN        NaN
# 629  ok so we think we have a plan for the notion c...      NaN        NaN
#
#      num_participants         user      thred_ts parent_user_id  thanks  \
# 579               NaN  U01S79YDELR  1.619420e+09    U01RS9Y6UJH       0
# 580               NaN  U01RXCQHMHT  1.619420e+09    U01RS9Y6UJH       0
# 581               NaN  U01RS9Y6UJH  1.619420e+09    U01RS9Y6UJH       0
# 582               NaN  U01S7KCL3DF  1.619420e+09    U01RS9Y6UJH       0
# 583               NaN  U01RW140HBP  1.619420e+09    U01RS9Y6UJH       0
# 584               NaN  U01RXCQHMHT  1.619424e+09            NaN       0
# 585               NaN  U01RN7BVD1C           NaN            NaN       0
# 586               NaN  U01S081EULS  1.619439e+09            NaN       0
# 587               NaN  U01S79YDELR  1.619439e+09    U01S081EULS       0
# 588               NaN  U01S79YDELR  1.619439e+09    U01S081EULS       0
# 589               NaN  U01S081EULS  1.619439e+09    U01S081EULS       0
# 590               NaN  U01S79YDELR  1.619424e+09    U01RXCQHMHT       0
# 591               NaN  U01S79YDELR           NaN            NaN       0
# 593               NaN  U01RUTP1ZQB           NaN            NaN       0
# 594               NaN  U01RW140HBP           NaN            NaN       0
# 595               NaN  U01SK96QF5E  1.619368e+09    U01S79YDELR       0
# 596               NaN  U01RXCQHMHT  1.619424e+09    U01RXCQHMHT       0
# 597               NaN  U01RW140HBP  1.619368e+09    U01S79YDELR       0
# 598               NaN  U01SJKB2MG8  1.619368e+09    U01S79YDELR       0
# 599               NaN  U01RW140HBP  1.619368e+09    U01S79YDELR       0
# 600               NaN  U01SJKB2MG8  1.619368e+09    U01S79YDELR       0
# 601               NaN  U01RW140HBP  1.619368e+09    U01S79YDELR       0
# 602               NaN  U01RW140HBP  1.619368e+09    U01S79YDELR       0
# 603               NaN  U01S79YDELR  1.619424e+09    U01RXCQHMHT       0
# 604               NaN  U01S7KCL3DF  1.619420e+09    U01RS9Y6UJH       0
# 605               NaN  U01RW140HBP  1.619420e+09    U01RS9Y6UJH       0
# 606               NaN  U01RW140HBP           NaN            NaN       0
# 607               NaN  U01RW140HBP  1.619508e+09            NaN       0
# 608               NaN  U01S7KCL3DF  1.619508e+09    U01RW140HBP       0
# 609               NaN  U01RW140HBP  1.619508e+09    U01RW140HBP       0
# 610               NaN  U01S7KCL3DF  1.619508e+09    U01RW140HBP       0
# 611               NaN  U01S7KCL3DF  1.619508e+09    U01RW140HBP       0
# 612               NaN  U01RW140HBP  1.619508e+09    U01RW140HBP       0
# 613               NaN  U01RW140HBP           NaN            NaN       0
# 614               NaN  U01RW140HBP  1.619519e+09            NaN       0
# 615               NaN  U01RW140HBP  1.619519e+09            NaN       0
# 616               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 617               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 618               NaN  U01RXCQHMHT  1.619519e+09    U01RW140HBP       0
# 619               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 620               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 621               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 622               NaN  U01S7BM4N81  1.619519e+09    U01RW140HBP       0
# 623               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 624               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 625               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 626               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 627               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 628               NaN  U01RW140HBP  1.619519e+09    U01RW140HBP       0
# 629               NaN  U01RW140HBP           NaN            NaN       0
#
#      polarity  p_rating                           emo  \
# 579  0.000000        Na                           NaN
# 580  0.916667  Positive                           NaN
# 581  0.250000   Neutral        face_with_rolling_eyes
# 582 -0.025000  Negative                           NaN
# 583  0.500000  Positive                           NaN
# 584  0.000000        Na                           NaN
# 585 -0.154762  Negative                           NaN
# 586  0.100000   Neutral         slightly_smiling_face
# 587  0.000000        Na                           NaN
# 588  0.500000  Positive                           NaN
# 589  0.000000        Na         slightly_smiling_face
# 590  0.000000        Na                           NaN
# 591 -0.300000  Negative                           NaN
# 593 -0.300000  Negative         slightly_smiling_face
# 594  0.000000        Na                           NaN
# 595  1.000000  Positive                           NaN
# 596  0.050000   Neutral         slightly_smiling_face
# 597  0.700000  Positive                           NaN
# 598  0.000000        Na                           NaN
# 599  0.875000  Positive                           NaN
# 600  0.500000  Positive                           NaN
# 601  0.625000  Positive                           NaN
# 602  0.600000  Positive                           NaN
# 603  0.500000  Positive         slightly_smiling_face
# 604  0.700000  Positive                       snowman
# 605  0.000000        Na                           NaN
# 606  0.500000  Positive                           NaN
# 607  0.160937   Neutral                           NaN
# 608  0.000000        Na                           NaN
# 609  0.500000  Positive                           NaN
# 610  0.450000   Neutral   walking distance from home
# 611 -0.416667  Negative                  disappointed
# 612  0.116667   Neutral                           NaN
# 613 -0.500000  Negative                           NaN
# 614  0.317411   Neutral                           NaN
# 615  0.162500   Neutral                           NaN
# 616  0.433333   Neutral                           NaN
# 617  0.000000        Na                           NaN
# 618  0.039286   Neutral                           NaN
# 619  0.600000  Positive                           NaN
# 620  0.100000   Neutral                 thinking_face
# 621  0.000000        Na         slightly_smiling_face
# 622  0.000000        Na                        python
# 623  0.000000        Na                           NaN
# 624  0.145833   Neutral                           NaN
# 625  0.200000   Neutral                           NaN
# 626  0.000000        Na                           NaN
# 627  0.625000  Positive                           NaN
# 628  0.325000   Neutral                           NaN
# 629  0.145000   Neutral                           NaN
#
#                                              questions keyword
# 579                                                 no
# 580                                                 no
# 581                                                 no
# 582                                                 no
# 583                                                 no
# 584                                                 no
# 585  we start at 14:30 right? Sorry I'm not sure an...
# 586  Yes! Can someone share here the Dataset from K...
# 587                                                 no
# 588            do you want the file or is the link ok?
# 589                                                 no
# 590  is this with the modifications she made in class?
# 591                                                 no
# 593                                                 no
# 594                                                 no
# 595                                                 no
# 596                                                 no
# 597  hmmm let me think on it - could it be a good w...
# 598  we could create a different view of the the ca...
# 599                                                 no
# 600                                                 no
# 601                                                 no
# 602                                                 no
# 603                                                 no
# 604                                                 no
# 605                                                 no
# 606                                                 no
# 607                                                 no
# 608                                                 no
# 609                                                 no
# 610                                                 no
# 611                                                 no
# 612                                                 no
# 613                                                 no
# 614  If you find yourself with some downtime this a...
# 615  ( i find bad news when delivered by a cute dog...
# 616  Is there an easy way to copy those notion page...
# 617                                                 no
# 618  it's probably not possible to copy the whole B...
# 619                                                 no
# 620  hmm :thinking_face: it looks like i might be a...
# 621                                                 no
# 622                                                 no
# 623                                                 no
# 624                                                 no
# 625                                                 no
# 626                                                 no
# 627                                                 no
# 628                                                 no
# 629                                                 no

# %%
df.to_csv('maindataframe.csv')
